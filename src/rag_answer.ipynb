# %%
import json
import torch
import numpy as np
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from sklearn.metrics.pairwise import cosine_similarity

# %%
embedder = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# %%
docs_file = "docs.jsonl"
documents = []
with open(docs_file, "r", encoding="utf-8") as f:
    for line in f:
        record = json.loads(line)
        title = record.get("title", "Untitled")
        text = record.get("text", "")
        documents.append(f"{title} : {text}")

# %%
documents
# Out:
# ['OrionSearch : It supports field-level boosting and phrase queries. The query language supports proximity operators using `~k` syntax. OrionSearch serves as a full-text search engine with BM25 ranking.',
#  'OrionSearch : Synonym expansion is configured in `orion.yml`. The indexer uses incremental segment merges.',
#  'OrionSearch : OrionSearch community survey results will be published next quarter.',
#  'OrionSearch : Users on forums discussed OrionSearch tutorials and workshop schedules.',
#  'OrionSearch : OrionSearch release notes mention minor UI tweaks and logging improvements.',
#  'ANLP : It provides sentence splitting, NER, and lemmatization for 50+ languages. Dictionaries are configured in `atlas.yml`. AtlasNLP has a rule-based fallback for rare tokens.',
#  'ANLP : AtlasNLP is a multilingual text processing suite. Models are packaged in ONNX format for portability.',
#  'Atlas NLP : Atlas NLP community survey results will be published next quarter.',
#  'Nebula DB : It supports JSON documents with automatic schema inference.',
#  'NebulaDB : NebulaDB uses a CRDT-based replication protocol for offline-first apps. The default port for NebulaDB is 7342. NebulaDB provides role-based access control with three roles: reader, writer, admin. Defaults are sensible for most users.',
#  'NebulaDB : NebulaDB is a lightweight document store built for edge devices.',
#  'NDB : NDB release notes mention minor UI tweaks and logging improvements.',
#  'Nebula DB : Users on forums discussed Nebula DB tutorials and workshop schedules.',
#  'Mercury RL : Trajectories can be exported to NumPy NPZ files. MercuryRL is a reinforcement learning toolkit for robotics.',
#  'MRL : It includes PPO and SAC reference implementations. Sim2real transfer is assisted by domain randomization utilities. MercuryRL uses YAML experiment manifests.',
#  'MRL : MRL release notes mention minor UI tweaks and logging improvements.',
#  'Mercury RL : Mercury RL release notes mention minor UI tweaks and logging improvements.',
#  'VulcanGraph : It supports ACID transactions with snapshot isolation. Indexes can be created per label and property.',
#  'VulcanGraph : VulcanGraph is a property graph database with Gremlin-like traversal. Bulk loads stream via CSV with a `vgraph load` command. It exposes a REST API on port 7787 by default.',
#  'VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.',
#  'VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.',
#  'VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.',
#  'VulcanGraph : VulcanGraph community survey results will be published next quarter.']

# %%
doc_embeddings = embedder.encode(documents, convert_to_tensor=True, normalize_embeddings=True, device='cpu')

# %%
doc_embeddings[0]
# Out:
# tensor([-9.6050e-03, -3.1252e-03,  9.2519e-03, -1.1618e-02, -4.1495e-02,
#          3.2064e-02,  1.6411e-02,  1.2942e-03, -2.3323e-02,  4.2615e-03,
#          1.3207e-02,  2.2988e-02,  5.1102e-02, -1.2245e-02,  4.6949e-02,
#          6.2586e-02,  1.6964e-02,  6.2505e-02, -2.8696e-02, -8.7659e-02,
#          4.2277e-02, -3.3239e-03,  5.7735e-02,  7.4101e-02, -4.1863e-02,
#         -5.1694e-02,  3.0393e-02,  5.1816e-04, -2.3950e-02,  9.3242e-02,
#          7.9909e-02, -3.2925e-02, -2.1849e-02, -1.0177e-01,  6.8444e-02,
#          8.3284e-02, -5.7564e-02,  2.7694e-02,  3.4352e-02,  2.5059e-02,
#          4.3552e-02,  7.8179e-02, -9.7161e-02,  8.1971e-02, -5.9552e-02,
#          2.4873e-02, -5.5834e-02, -2.1729e-02, -2.2279e-02, -3.1736e-02,
#          3.9857e-02, -2.2533e-02, -6.6579e-03,  3.1638e-02, -4.2241e-02,
#          7.4087e-02, -5.3228e-02, -1.5505e-03,  8.7885e-02])

# %%
model_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto"
)

generator = pipeline("text-generation", model=model, tokenizer=tokenizer)
# Out:
# Device set to use cuda:0

# %%
with open("questions.json", "r", encoding="utf-8") as f:
    questions = json.load(f)

# %%
questions
# Out:
# [{'id': 'q0',
#   'question': 'What ranking function does OrionSearch use?',
#   'answers': ['BM25', 'bm25']},
#  {'id': 'q1',
#   'question': 'State a key feature of OrionSearch.',
#   'answers': ['supports', 'field-level', 'boosting', 'phrase', 'queries']},
#  {'id': 'q2',
#   'question': 'State a key feature of OrionSearch.',
#   'answers': ['indexer', 'uses', 'incremental', 'segment', 'merges']},
#  {'id': 'q3',
#   'question': 'State a key feature of OrionSearch.',
#   'answers': ['synonym', 'expansion', 'configured', 'orion.yml']},
#  {'id': 'q4',
#   'question': 'State a key feature of OrionSearch.',
#   'answers': ['query',
#    'language',
#    'supports',
#    'proximity',
#    'operators',
#    'using']},
#  {'id': 'q5',
#   'question': 'State a key feature of AtlasNLP.',
#   'answers': ['atlasnlp', 'multilingual', 'text', 'processing', 'suite']},
#  {'id': 'q6',
#   'question': 'State a key feature of AtlasNLP.',
#   'answers': ['provides',
#    'sentence',
#    'splitting',
#    'lemmatization',
#    'languages']},
#  {'id': 'q7',
#   'question': 'In what format are AtlasNLP models packaged for portability?',
#   'answers': ['ONNX', 'onnx']},
#  {'id': 'q8',
#   'question': 'State a key feature of AtlasNLP.',
#   'answers': ['atlasnlp', 'rule-based', 'fallback', 'rare', 'tokens']},
#  {'id': 'q9',
#   'question': 'State a key feature of AtlasNLP.',
#   'answers': ['dictionaries', 'configured', 'atlas.yml']},
#  {'id': 'q10',
#   'question': 'State a key feature of NebulaDB.',
#   'answers': ['nebuladb',
#    'lightweight',
#    'document',
#    'store',
#    'built',
#    'edge']},
#  {'id': 'q11',
#   'question': 'State a key feature of NebulaDB.',
#   'answers': ['supports', 'json', 'documents', 'with', 'automatic', 'schema']},
#  {'id': 'q12',
#   'question': 'State a key feature of NebulaDB.',
#   'answers': ['nebuladb',
#    'uses',
#    'crdt-based',
#    'replication',
#    'protocol',
#    'offline-first']},
#  {'id': 'q13',
#   'question': 'What is the default port for NebulaDB?',
#   'answers': ['7342', 'port 7342']},
#  {'id': 'q14',
#   'question': 'Name one role available in NebulaDB RBAC.',
#   'answers': ['reader', 'writer', 'admin']},
#  {'id': 'q15',
#   'question': 'Name one RL algorithm included in MercuryRL.',
#   'answers': ['PPO', 'SAC', 'ppo', 'sac']},
#  {'id': 'q16',
#   'question': 'Name one RL algorithm included in MercuryRL.',
#   'answers': ['PPO', 'SAC', 'ppo', 'sac']},
#  {'id': 'q17',
#   'question': 'Name one RL algorithm included in MercuryRL.',
#   'answers': ['PPO', 'SAC', 'ppo', 'sac']},
#  {'id': 'q18',
#   'question': 'Name one RL algorithm included in MercuryRL.',
#   'answers': ['PPO', 'SAC', 'ppo', 'sac']},
#  {'id': 'q19',
#   'question': 'Name one RL algorithm included in MercuryRL.',
#   'answers': ['PPO', 'SAC', 'ppo', 'sac']},
#  {'id': 'q20',
#   'question': 'State a key feature of VulcanGraph.',
#   'answers': ['vulcangraph',
#    'property',
#    'graph',
#    'database',
#    'with',
#    'gremlin-like']},
#  {'id': 'q21',
#   'question': 'State a key feature of VulcanGraph.',
#   'answers': ['supports',
#    'acid',
#    'transactions',
#    'with',
#    'snapshot',
#    'isolation']},
#  {'id': 'q22',
#   'question': 'State a key feature of VulcanGraph.',
#   'answers': ['indexes', 'created', 'label', 'property']},
#  {'id': 'q23',
#   'question': 'State a key feature of VulcanGraph.',
#   'answers': ['bulk', 'loads', 'stream', 'with', 'vgraph', 'load']},
#  {'id': 'q24',
#   'question': 'What is the default port for VulcanGraph?',
#   'answers': ['7787', 'port 7787']}]

# %%
rag_answers = {}

for i, q in enumerate(questions):
    question_text = q if isinstance(q, str) else q.get("question", "")


    query_embedding = embedder.encode(question_text, convert_to_tensor=True, normalize_embeddings=True, device='cpu')

    cos_scores = cosine_similarity(
        query_embedding.cpu().numpy().reshape(1, -1),
        doc_embeddings.cpu().numpy()
    )[0]
    top_indices = np.argsort(cos_scores)[::-1][:5]
    top_docs = [documents[idx] for idx in top_indices]
    context = "\n".join(top_docs)


    print(f"\nQuestion {i+1}: {question_text}")
    print("Retrieved context:")
    for doc in top_docs:
        print("-", doc)

    prompt = f"""
Answer the following question using ONLY the context provided.
Give a short, clear answer.

Context:
{context}

Question:
{question_text}

Answer:
"""

    output = generator(prompt, max_new_tokens=50, do_sample=True, temperature=0.7)
    answer = output[0]["generated_text"].split("Answer:")[-1].strip()

    rag_answers[f"q{i}"] = answer
    print("Generated answer:", answer)
    print("-"*60)
# Out:
# Question 1: What ranking function does OrionSearch use?
# Retrieved context:
# - OrionSearch : OrionSearch community survey results will be published next quarter.
# - OrionSearch : It supports field-level boosting and phrase queries. The query language supports proximity operators using `~k` syntax. OrionSearch serves as a full-text search engine with BM25 ranking.
# - OrionSearch : Users on forums discussed OrionSearch tutorials and workshop schedules.
# - OrionSearch : OrionSearch release notes mention minor UI tweaks and logging improvements.
# - OrionSearch : Synonym expansion is configured in `orion.yml`. The indexer uses incremental segment merges.
# Generated answer: OrionSearch uses BM25 ranking, which is a hybrid algorithm that combines two popular ranking functions, Boosted Term Frequency (BM25) and Incremental Term Frequency (ITF).
# ------------------------------------------------------------
#
# Question 2: State a key feature of OrionSearch.
# Retrieved context:
# - OrionSearch : Users on forums discussed OrionSearch tutorials and workshop schedules.
# - OrionSearch : OrionSearch community survey results will be published next quarter.
# - OrionSearch : OrionSearch release notes mention minor UI tweaks and logging improvements.
# - OrionSearch : Synonym expansion is configured in `orion.yml`. The indexer uses incremental segment merges.
# - OrionSearch : It supports field-level boosting and phrase queries. The query language supports proximity operators using `~k` syntax. OrionSearch serves as a full-text search engine with BM25 ranking.
# Generated answer: OrionSearch supports field-level boosting and phrase queries. The query language supports proximity operators using `~k` syntax.
# ------------------------------------------------------------
#
# Question 3: State a key feature of OrionSearch.
# Retrieved context:
# - OrionSearch : Users on forums discussed OrionSearch tutorials and workshop schedules.
# - OrionSearch : OrionSearch community survey results will be published next quarter.
# - OrionSearch : OrionSearch release notes mention minor UI tweaks and logging improvements.
# - OrionSearch : Synonym expansion is configured in `orion.yml`. The indexer uses incremental segment merges.
# - OrionSearch : It supports field-level boosting and phrase queries. The query language supports proximity operators using `~k` syntax. OrionSearch serves as a full-text search engine with BM25 ranking.
# Generated answer: OrionSearch supports field-level boosting and phrase queries, which allows developers to fine-tune search results based on user relevance.
# ------------------------------------------------------------
#
# Question 4: State a key feature of OrionSearch.
# Retrieved context:
# - OrionSearch : Users on forums discussed OrionSearch tutorials and workshop schedules.
# - OrionSearch : OrionSearch community survey results will be published next quarter.
# - OrionSearch : OrionSearch release notes mention minor UI tweaks and logging improvements.
# - OrionSearch : Synonym expansion is configured in `orion.yml`. The indexer uses incremental segment merges.
# - OrionSearch : It supports field-level boosting and phrase queries. The query language supports proximity operators using `~k` syntax. OrionSearch serves as a full-text search engine with BM25 ranking.
# Generated answer: OrionSearch supports field-level boosting and phrase queries.
# ------------------------------------------------------------
#
# Question 5: State a key feature of OrionSearch.
# Retrieved context:
# - OrionSearch : Users on forums discussed OrionSearch tutorials and workshop schedules.
# - OrionSearch : OrionSearch community survey results will be published next quarter.
# - OrionSearch : OrionSearch release notes mention minor UI tweaks and logging improvements.
# - OrionSearch : Synonym expansion is configured in `orion.yml`. The indexer uses incremental segment merges.
# - OrionSearch : It supports field-level boosting and phrase queries. The query language supports proximity operators using `~k` syntax. OrionSearch serves as a full-text search engine with BM25 ranking.
# Generated answer: Key feature: OrionSearch supports field-level boosting and phrase queries.
# ------------------------------------------------------------
#
# Question 6: State a key feature of AtlasNLP.
# Retrieved context:
# - ANLP : AtlasNLP is a multilingual text processing suite. Models are packaged in ONNX format for portability.
# - Atlas NLP : Atlas NLP community survey results will be published next quarter.
# - ANLP : It provides sentence splitting, NER, and lemmatization for 50+ languages. Dictionaries are configured in `atlas.yml`. AtlasNLP has a rule-based fallback for rare tokens.
# - Nebula DB : It supports JSON documents with automatic schema inference.
# - VulcanGraph : VulcanGraph is a property graph database with Gremlin-like traversal. Bulk loads stream via CSV with a `vgraph load` command. It exposes a REST API on port 7787 by default.
# Generated answer: In context, AtlasNLP provides sentence splitting, NER, and lemmatization for 50+ languages.
# ------------------------------------------------------------
#
# Question 7: State a key feature of AtlasNLP.
# Retrieved context:
# - ANLP : AtlasNLP is a multilingual text processing suite. Models are packaged in ONNX format for portability.
# - Atlas NLP : Atlas NLP community survey results will be published next quarter.
# - ANLP : It provides sentence splitting, NER, and lemmatization for 50+ languages. Dictionaries are configured in `atlas.yml`. AtlasNLP has a rule-based fallback for rare tokens.
# - Nebula DB : It supports JSON documents with automatic schema inference.
# - VulcanGraph : VulcanGraph is a property graph database with Gremlin-like traversal. Bulk loads stream via CSV with a `vgraph load` command. It exposes a REST API on port 7787 by default.
# Generated answer: The key feature of AtlasNLP is its ability to handle a vast amount of textual data in a multilingual context. It provides sentence splitting, NER, and lemmatization for 50+ languages, dictionaries configured in at
# ------------------------------------------------------------
#
# Question 8: In what format are AtlasNLP models packaged for portability?
# Retrieved context:
# - ANLP : AtlasNLP is a multilingual text processing suite. Models are packaged in ONNX format for portability.
# - Atlas NLP : Atlas NLP community survey results will be published next quarter.
# - Nebula DB : It supports JSON documents with automatic schema inference.
# - ANLP : It provides sentence splitting, NER, and lemmatization for 50+ languages. Dictionaries are configured in `atlas.yml`. AtlasNLP has a rule-based fallback for rare tokens.
# - NebulaDB : NebulaDB is a lightweight document store built for edge devices.
# Generated answer: AtlasNLP models are packaged in ONNX format for portability.
# ------------------------------------------------------------
#
# Question 9: State a key feature of AtlasNLP.
# Retrieved context:
# - ANLP : AtlasNLP is a multilingual text processing suite. Models are packaged in ONNX format for portability.
# - Atlas NLP : Atlas NLP community survey results will be published next quarter.
# - ANLP : It provides sentence splitting, NER, and lemmatization for 50+ languages. Dictionaries are configured in `atlas.yml`. AtlasNLP has a rule-based fallback for rare tokens.
# - Nebula DB : It supports JSON documents with automatic schema inference.
# - VulcanGraph : VulcanGraph is a property graph database with Gremlin-like traversal. Bulk loads stream via CSV with a `vgraph load` command. It exposes a REST API on port 7787 by default.
# Generated answer: The key feature of AtlasNLP is its ability to package models in ONNX format for portability.
# ------------------------------------------------------------
#
# Question 10: State a key feature of AtlasNLP.
# Retrieved context:
# - ANLP : AtlasNLP is a multilingual text processing suite. Models are packaged in ONNX format for portability.
# - Atlas NLP : Atlas NLP community survey results will be published next quarter.
# - ANLP : It provides sentence splitting, NER, and lemmatization for 50+ languages. Dictionaries are configured in `atlas.yml`. AtlasNLP has a rule-based fallback for rare tokens.
# - Nebula DB : It supports JSON documents with automatic schema inference.
# - VulcanGraph : VulcanGraph is a property graph database with Gremlin-like traversal. Bulk loads stream via CSV with a `vgraph load` command. It exposes a REST API on port 7787 by default.
# Generated answer: AtlasNLP provides sentence splitting, NER, and lemmatization for 50+ languages.
# ------------------------------------------------------------
#
# Question 11: State a key feature of NebulaDB.
# Retrieved context:
# - Nebula DB : Users on forums discussed Nebula DB tutorials and workshop schedules.
# - NebulaDB : NebulaDB is a lightweight document store built for edge devices.
# - NebulaDB : NebulaDB uses a CRDT-based replication protocol for offline-first apps. The default port for NebulaDB is 7342. NebulaDB provides role-based access control with three roles: reader, writer, admin. Defaults are sensible for most users.
# - Nebula DB : It supports JSON documents with automatic schema inference.
# - OrionSearch : OrionSearch release notes mention minor UI tweaks and logging improvements.
# Generated answer: NebulaDB provides role-based access control for offline-first applications.
# ------------------------------------------------------------
#
# Question 12: State a key feature of NebulaDB.
# Retrieved context:
# - Nebula DB : Users on forums discussed Nebula DB tutorials and workshop schedules.
# - NebulaDB : NebulaDB is a lightweight document store built for edge devices.
# - NebulaDB : NebulaDB uses a CRDT-based replication protocol for offline-first apps. The default port for NebulaDB is 7342. NebulaDB provides role-based access control with three roles: reader, writer, admin. Defaults are sensible for most users.
# - Nebula DB : It supports JSON documents with automatic schema inference.
# - OrionSearch : OrionSearch release notes mention minor UI tweaks and logging improvements.
# Generated answer: NebulaDB offers role-based access control with three roles: reader, writer, and admin.
# ------------------------------------------------------------
#
# Question 13: State a key feature of NebulaDB.
# Retrieved context:
# - Nebula DB : Users on forums discussed Nebula DB tutorials and workshop schedules.
# - NebulaDB : NebulaDB is a lightweight document store built for edge devices.
# - NebulaDB : NebulaDB uses a CRDT-based replication protocol for offline-first apps. The default port for NebulaDB is 7342. NebulaDB provides role-based access control with three roles: reader, writer, admin. Defaults are sensible for most users.
# - Nebula DB : It supports JSON documents with automatic schema inference.
# - OrionSearch : OrionSearch release notes mention minor UI tweaks and logging improvements.
# Generated answer: The key feature of NebulaDB is its CRDT-based replication protocol for offline-first apps.
# ------------------------------------------------------------
#
# Question 14: What is the default port for NebulaDB?
# Retrieved context:
# - NebulaDB : NebulaDB uses a CRDT-based replication protocol for offline-first apps. The default port for NebulaDB is 7342. NebulaDB provides role-based access control with three roles: reader, writer, admin. Defaults are sensible for most users.
# - Nebula DB : Users on forums discussed Nebula DB tutorials and workshop schedules.
# - NebulaDB : NebulaDB is a lightweight document store built for edge devices.
# - Nebula DB : It supports JSON documents with automatic schema inference.
# - OrionSearch : Users on forums discussed OrionSearch tutorials and workshop schedules.
# Generated answer: The default port for NebulaDB is 7342.
# ------------------------------------------------------------
#
# Question 15: Name one role available in NebulaDB RBAC.
# Retrieved context:
# - Nebula DB : Users on forums discussed Nebula DB tutorials and workshop schedules.
# - NebulaDB : NebulaDB uses a CRDT-based replication protocol for offline-first apps. The default port for NebulaDB is 7342. NebulaDB provides role-based access control with three roles: reader, writer, admin. Defaults are sensible for most users.
# - NebulaDB : NebulaDB is a lightweight document store built for edge devices.
# - Nebula DB : It supports JSON documents with automatic schema inference.
# - OrionSearch : Users on forums discussed OrionSearch tutorials and workshop schedules.
# Generated answer: Writer
# ------------------------------------------------------------
#
# Question 16: Name one RL algorithm included in MercuryRL.
# Retrieved context:
# - Mercury RL : Trajectories can be exported to NumPy NPZ files. MercuryRL is a reinforcement learning toolkit for robotics.
# - Mercury RL : Mercury RL release notes mention minor UI tweaks and logging improvements.
# - MRL : It includes PPO and SAC reference implementations. Sim2real transfer is assisted by domain randomization utilities. MercuryRL uses YAML experiment manifests.
# - VulcanGraph : It supports ACID transactions with snapshot isolation. Indexes can be created per label and property.
# - VulcanGraph : VulcanGraph is a property graph database with Gremlin-like traversal. Bulk loads stream via CSV with a `vgraph load` command. It exposes a REST API on port 7787 by default.
# Generated answer: 1. PPO
# ------------------------------------------------------------
#
# Question 17: Name one RL algorithm included in MercuryRL.
# Retrieved context:
# - Mercury RL : Trajectories can be exported to NumPy NPZ files. MercuryRL is a reinforcement learning toolkit for robotics.
# - Mercury RL : Mercury RL release notes mention minor UI tweaks and logging improvements.
# - MRL : It includes PPO and SAC reference implementations. Sim2real transfer is assisted by domain randomization utilities. MercuryRL uses YAML experiment manifests.
# - VulcanGraph : It supports ACID transactions with snapshot isolation. Indexes can be created per label and property.
# - VulcanGraph : VulcanGraph is a property graph database with Gremlin-like traversal. Bulk loads stream via CSV with a `vgraph load` command. It exposes a REST API on port 7787 by default.
# Generated answer: Verified answer: SAC (Soft Actor-Critic)
# ------------------------------------------------------------
#
# Question 18: Name one RL algorithm included in MercuryRL.
# Retrieved context:
# - Mercury RL : Trajectories can be exported to NumPy NPZ files. MercuryRL is a reinforcement learning toolkit for robotics.
# - Mercury RL : Mercury RL release notes mention minor UI tweaks and logging improvements.
# - MRL : It includes PPO and SAC reference implementations. Sim2real transfer is assisted by domain randomization utilities. MercuryRL uses YAML experiment manifests.
# - VulcanGraph : It supports ACID transactions with snapshot isolation. Indexes can be created per label and property.
# - VulcanGraph : VulcanGraph is a property graph database with Gremlin-like traversal. Bulk loads stream via CSV with a `vgraph load` command. It exposes a REST API on port 7787 by default.
# Generated answer: SAC
# ------------------------------------------------------------
#
# Question 19: Name one RL algorithm included in MercuryRL.
# Retrieved context:
# - Mercury RL : Trajectories can be exported to NumPy NPZ files. MercuryRL is a reinforcement learning toolkit for robotics.
# - Mercury RL : Mercury RL release notes mention minor UI tweaks and logging improvements.
# - MRL : It includes PPO and SAC reference implementations. Sim2real transfer is assisted by domain randomization utilities. MercuryRL uses YAML experiment manifests.
# - VulcanGraph : It supports ACID transactions with snapshot isolation. Indexes can be created per label and property.
# - VulcanGraph : VulcanGraph is a property graph database with Gremlin-like traversal. Bulk loads stream via CSV with a `vgraph load` command. It exposes a REST API on port 7787 by default.
# Generated answer: SAC
# ------------------------------------------------------------
#
# Question 20: Name one RL algorithm included in MercuryRL.
# Retrieved context:
# - Mercury RL : Trajectories can be exported to NumPy NPZ files. MercuryRL is a reinforcement learning toolkit for robotics.
# - Mercury RL : Mercury RL release notes mention minor UI tweaks and logging improvements.
# - MRL : It includes PPO and SAC reference implementations. Sim2real transfer is assisted by domain randomization utilities. MercuryRL uses YAML experiment manifests.
# - VulcanGraph : It supports ACID transactions with snapshot isolation. Indexes can be created per label and property.
# - VulcanGraph : VulcanGraph is a property graph database with Gremlin-like traversal. Bulk loads stream via CSV with a `vgraph load` command. It exposes a REST API on port 7787 by default.
# Generated answer: PPO
# ------------------------------------------------------------
#
# Question 21: State a key feature of VulcanGraph.
# Retrieved context:
# - VulcanGraph : VulcanGraph community survey results will be published next quarter.
# - VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.
# - VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.
# - VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.
# - VulcanGraph : VulcanGraph is a property graph database with Gremlin-like traversal. Bulk loads stream via CSV with a `vgraph load` command. It exposes a REST API on port 7787 by default.
# Generated answer: State that VulcanGraph is a property graph database with Gremlin-like traversal, Bulk Loads, and a REST API on port 7787 by default.
# ------------------------------------------------------------
#
# Question 22: State a key feature of VulcanGraph.
# Retrieved context:
# - VulcanGraph : VulcanGraph community survey results will be published next quarter.
# - VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.
# - VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.
# - VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.
# - VulcanGraph : VulcanGraph is a property graph database with Gremlin-like traversal. Bulk loads stream via CSV with a `vgraph load` command. It exposes a REST API on port 7787 by default.
# Generated answer: VulcanGraph offers bulk loading via CSV with a `vgraph load` command, which exposes a REST API on port 7787 by default.
# ------------------------------------------------------------
#
# Question 23: State a key feature of VulcanGraph.
# Retrieved context:
# - VulcanGraph : VulcanGraph community survey results will be published next quarter.
# - VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.
# - VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.
# - VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.
# - VulcanGraph : VulcanGraph is a property graph database with Gremlin-like traversal. Bulk loads stream via CSV with a `vgraph load` command. It exposes a REST API on port 7787 by default.
# Generated answer: A key feature of VulcanGraph is its ability to load bulk data in a streaming manner.
# ------------------------------------------------------------
#
# Question 24: State a key feature of VulcanGraph.
# Retrieved context:
# - VulcanGraph : VulcanGraph community survey results will be published next quarter.
# - VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.
# - VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.
# - VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.
# - VulcanGraph : VulcanGraph is a property graph database with Gremlin-like traversal. Bulk loads stream via CSV with a `vgraph load` command. It exposes a REST API on port 7787 by default.
# Generated answer: VulcanGraph is a property graph database with Gremlin-like traversal.
# ------------------------------------------------------------
#
# Question 25: What is the default port for VulcanGraph?
# Retrieved context:
# - VulcanGraph : VulcanGraph community survey results will be published next quarter.
# - VulcanGraph : VulcanGraph is a property graph database with Gremlin-like traversal. Bulk loads stream via CSV with a `vgraph load` command. It exposes a REST API on port 7787 by default.
# - VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.
# - VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.
# - VulcanGraph : VulcanGraph release notes mention minor UI tweaks and logging improvements.
# Generated answer: The default port for VulcanGraph is port 7787.
# ------------------------------------------------------------

# %%
with open("rag_answers.json", "w", encoding="utf-8") as f:
    json.dump(rag_answers, f, indent=2, ensure_ascii=False)

print("✅ All answers saved to rag_answers.json")
# Out:
# ✅ All answers saved to rag_answers.json
